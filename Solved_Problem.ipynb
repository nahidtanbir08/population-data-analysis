# %%
import pandas as pd

df = pd.read_csv("population2.csv")

print(df.head())
# Out:
#        District  registered voters  Total population  Unnamed: 3    DIST UPPER
# 0        Achham             257477            127742         NaN        ACHHAM
# 1  Arghakhanchi             197632            126699         NaN  ARGHAKHANCHI
# 2       Baglung             268613            156802         NaN       BAGLUNG
# 3       Baitadi             250898            124824         NaN       BAITADI
# 4       Bajhang             195159             97610         NaN       BAJHANG

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("population2.csv")

# %%
df.columns = ['District', 'Registered_Voters', 'Total_Population', 'Drop', 'Dist_Upper']
df = df[['District', 'Registered_Voters', 'Total_Population', 'Dist_Upper']]

# %%
voters = df['Registered_Voters'].to_numpy()
population = df['Total_Population'].to_numpy()
districts = df['District'].to_numpy()

# %% [markdown]
# ## Question1

# %%
mask = population > 6000
print("Mask (Population > 60,00):")
print(mask)
# Out:
# Mask (Population > 60,00):
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True]

# %% [markdown]
# ## Question 2

# %%
min_voters =np. min(voters) 
max_voter = np. max(voters)
print ("Minimum Registered Voters:", min_voters)
print ("Maximum registered Voters:", max_voters)
# Out:
# Minimum Registered Voters: 6538
# Maximum registered Voters: 1744240

# %% [markdown]
# ## Question 3

# %%
min_index = np.argmin(population)
print("District with Lowest Population:", districts[min_index])
print("Population:", population[min_index])
# Out:
# District with Lowest Population: Manang
# Population: 5095

# %% [markdown]
# ## Question 4
